# %% [markdown]
# Claro! Aqui está o resumo completo da instalação e configuração do ambiente virtual (`venv`) no endereço `C:\Py\venv`, incluindo a criação de aliases no PowerShell e o uso do JupyterLab:
#
# ---
#
# ### **Resumo: Instalação e Configuração do `venv` no Windows**
#
# #### 1. **Instalação do Python**
# - Baixe e instale o Python a partir do site oficial: [python.org](https://www.python.org/).
# - Durante a instalação, marque a opção **"Add Python to PATH"** para facilitar o uso do Python no terminal.
#
# #### 2. **Criação do Ambiente Virtual**
# 1. Abra o PowerShell.
# 2. Navegue até o diretório onde deseja criar o ambiente virtual (opcional):
#    ```powershell
#    cd C:\Py
#    ```
# 3. Crie o ambiente virtual:
#    ```powershell
#    python -m venv venv
#    ```
#    - Isso criará uma pasta chamada `venv` em `C:\Py`.
#
# #### 3. **Ativação do Ambiente Virtual**
# 1. Navegue até a pasta `Scripts` do ambiente virtual:
#    ```powershell
#    cd C:\Py\venv\Scripts
#    ```
# 2. Execute o script de ativação:
#    ```powershell
#    .\activate
#    ```
#    - O prompt do PowerShell mudará para `(venv)`, indicando que o ambiente virtual está ativo.
#
# #### 4. **Instalação de Bibliotecas**
# Com o ambiente virtual ativo, instale as bibliotecas necessárias usando `pip`. Por exemplo:
# ```powershell
# pip install jupyterlab pandas numpy
# ```
#
# #### 5. **Configuração de Aliases no PowerShell**
# Para facilitar a ativação do ambiente virtual, crie um alias no perfil do PowerShell:
# 1. Abra o arquivo de perfil:
#    ```powershell
#    notepad $PROFILE
#    ```
# 2. Adicione a função para ativar o ambiente virtual:
#    ```powershell
#    function activateVenv {
#        . C:\Py\venv\Scripts\activate.ps1
#    }
#    ```
# 3. Salve o arquivo e recarregue o perfil:
#    ```powershell
#    . $PROFILE
#    ```
# 4. Agora, você pode ativar o ambiente virtual digitando:
#    ```powershell
#    activateVenv
#    ```
#
# #### 6. **Uso do JupyterLab**
# 1. Com o ambiente virtual ativo, instale o JupyterLab:
#    ```powershell
#    pip install jupyterlab
#    ```
# 2. Inicie o JupyterLab:
#    ```powershell
#    jupyter lab
#    ```
#    - Isso abrirá o JupyterLab no seu navegador padrão.
#
# #### 7. **Desativação do Ambiente Virtual**
# Para desativar o ambiente virtual, use:
# ```powershell
# deactivate
# ```
#
# ---
#
# ### **Exemplo de Uso no JupyterLab**
# 1. Abra o JupyterLab com o ambiente virtual ativo.
# 2. Crie um novo notebook Python.
# 3. Verifique o ambiente virtual no notebook:
#    ```python
#    import sys
#    print(sys.executable)
#    ```
#    - O caminho exibido deve apontar para o Python dentro da pasta `C:\Py\venv`.
#
# ---
#
# Esse resumo cobre todos os passos necessários para instalar, configurar e usar o ambiente virtual no Windows, incluindo a integração com o JupyterLab. Se precisar de mais detalhes ou ajuda, é só avisar! 😊
