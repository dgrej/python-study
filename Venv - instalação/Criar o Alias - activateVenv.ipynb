# %% [markdown]
# Criar um **alias no PowerShell** para ativar o ambiente virtual digitando apenas `activateVenv` é uma ótima ideia! Isso facilita muito o seu fluxo de trabalho. Vou te mostrar como fazer isso passo a passo.
#
# ---
#
# ### Passos para Criar o Alias `activateVenv`
#
# 1. **Abra o Arquivo de Perfil do PowerShell**:
#    O perfil do PowerShell é um script que é executado sempre que você abre uma nova sessão do PowerShell. Para editá-lo, execute o seguinte comando:
#    ```powershell
#    notepad $PROFILE
#    ```
#    - Se o arquivo não existir, o PowerShell perguntará se deseja criá-lo. Confirme.
#
# 2. **Adicione a Função ao Perfil**:
#    No arquivo que abriu no Notepad, adicione a seguinte função:
#    ```powershell
#    function activateVenv {
#        . C:\Py\venv\Scripts\activate.ps1
#    }
#    ```
#    - Aqui, `C:\Py\venv\Scripts\activate.ps1` é o caminho completo para o script de ativação do seu ambiente virtual. Certifique-se de que o caminho está correto.
#
# 3. **Salve e Feche o Arquivo**:
#    - Salve o arquivo no Notepad e feche-o.
#
# 4. **Recarregue o Perfil**:
#    Para que as alterações entrem em vigor, recarregue o perfil do PowerShell:
#    ```powershell
#    . $PROFILE
#    ```
#
# 5. **Teste o Alias**:
#    Agora, você pode ativar o ambiente virtual simplesmente digitando:
#    ```powershell
#    activateVenv
#    ```
#    - O prompt deve mudar para `(venv)`, indicando que o ambiente virtual está ativo.
#
# ---
#
# ### Explicação do Código
# - **`function activateVenv { ... }`**: Define uma função chamada `activateVenv`.
# - **`. C:\Py\venv\Scripts\activate.ps1`**: O ponto (`.`) no início é usado no PowerShell para "executar" o script `activate.ps1` no escopo atual. Isso é necessário para que as variáveis de ambiente sejam configuradas corretamente.
#
# ---
#
# ### Dicas Adicionais
# 1. **Verifique o Caminho do `activate.ps1`**:
#    Certifique-se de que o caminho `C:\Py\venv\Scripts\activate.ps1` está correto. Se o seu ambiente virtual estiver em outro local, ajuste o caminho na função.
#
# 2. **Adicione Outros Aliases Úteis**:
#    Você pode adicionar outras funções ao seu perfil para facilitar tarefas comuns. Por exemplo:
#    ```powershell
#    function desativarVenv {
#        deactivate
#    }
#    ```
#    Agora, você pode desativar o ambiente virtual digitando `desativarVenv`.
#
# 3. **Compartilhe o Perfil**:
#    Se você trabalha em vários computadores, pode salvar o arquivo de perfil (`$PROFILE`) em um repositório Git ou na nuvem para sincronizar suas configurações entre máquinas.
#
# 4. **Problemas com o Perfil**:
#    Se o alias não funcionar após recarregar o perfil, verifique se o arquivo foi salvo corretamente e se o caminho do `activate.ps1` está correto.
#
# ---
#
# ### Exemplo Completo do Perfil
# Seu arquivo de perfil (`$PROFILE`) pode ficar assim:
# ```powershell
# # Ativar ambiente virtual
# function activateVenv {
#     . C:\Py\venv\Scripts\activate.ps1
# }
#
# # Desativar ambiente virtual
# function desativarVenv {
#     deactivate
# }
#
# # Outros aliases úteis
# function atualizarPip {
#     python -m pip install --upgrade pip
# }
# ```
#
# Agora, você pode usar `activateVenv`, `desativarVenv` e `atualizarPip` diretamente no PowerShell! 😊
#
# Se tiver mais dúvidas ou precisar de ajuda, é só avisar!
